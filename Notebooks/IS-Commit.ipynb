# %% [markdown]
# # 多群体视角下的情绪对股票市场的影响
# 2021级金融专硕鲍子睿 - 代码实现

# %% [markdown]
# ## 文件说明
# 本项目基于处理好的时间序列数据，展示各个章节的实验结果。其中Datasets中的csv数据文件是处理好的时间序列数据，Notebook下的文件IS-Commit和IS-Commit-2是可执行的代码文件，Notebook下的outputs目录为代码运行后的输出结果。

# %% [markdown]
# ### 代码运行环境
# Stata 17,python==3.10,numpy==1.24.3,pandas==2.0.2,matplotlib==3.7.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import numpy as np

# Stata 17
sys.path.append('/Applications/Stata/utilities')
from pystata import config

config.init('mp')
# Out:
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      17.0
# ___/   /   /___/   /   /___/       MP—Parallel Edition
#
#  Statistics and Data Science       Copyright 1985-2021 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-STATA-PC        https://www.stata.com
#                                    979-696-4600        stata@stata.com
#
# Stata license: Single-user 8-core , expiring  1 Jan 2025
# Serial number: 501709301094
#   Licensed to: Colin's Stata 17 MP
#                Love you
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. More than 2 billion observations are allowed; see help obs_advice.
#       3. Maximum number of variables is set to 5,000; see help set_maxvar.

# %% [markdown]
# ### 数据集准备
# 使用了已经处理好的时间序列数据，包含了使用深度学习提取的多个情绪特征

# %%
df_is = pd.read_csv('../DataSets/IS-TimeSeries.csv').astype(dtype={'trade_date': str})
df_is
# Out:
#       Unnamed: 0 trade_date    ts_code  CON_YEAR        CON_OR        CON_NP  \
# 0              7   20140102  000985.SH      2014  3.034892e+09  27421.678403
# 1             18   20140103  000985.SH      2014  3.033876e+09  27421.601209
# 2             29   20140106  000985.SH      2014  3.033345e+09  27412.012060
# 3             40   20140107  000985.SH      2014  3.028546e+09  27384.608096
# 4             51   20140108  000985.SH      2014  3.028892e+09  27355.547003
# ...          ...        ...        ...       ...           ...           ...
# 1939       21350   20211227  000985.SH      2021  6.389869e+09  53799.927579
# 1940       21361   20211228  000985.SH      2021  6.391559e+09  53788.880275
# 1941       21372   20211229  000985.SH      2021  6.389955e+09  53725.674838
# 1942       21383   20211230  000985.SH      2021  6.390729e+09  53695.625032
# 1943       21394   20211231  000985.SH      2021  6.389440e+09  53655.694957
#
#       CON_EPS        CON_NA  CON_PB  CON_PS  ...    NIPO_R    RIPO_R  \
# 0      0.6857  2.017385e+09  1.3334  0.8863  ... -0.993200 -0.429099
# 1      0.6857  2.017584e+09  1.3213  0.8787  ... -0.993200 -0.429099
# 2      0.6854  2.027389e+09  1.2895  0.8619  ... -0.993200 -0.429099
# 3      0.6846  2.027386e+09  1.2917  0.8647  ... -0.993200 -0.429099
# 4      0.6838  2.028490e+09  1.2935  0.8663  ... -0.993200 -0.429099
# ...       ...           ...     ...     ...  ...       ...       ...
# 1939   0.7131  5.236956e+09  1.7835  1.4617  ... -0.044895 -0.374305
# 1940   0.7129  5.237495e+09  1.7933  1.4695  ...  2.955105 -0.346122
# 1941   0.7120  5.237052e+09  1.7779  1.4571  ... -1.044895 -0.453585
# 1942   0.7116  5.236812e+09  1.7905  1.4672  ...  1.955105 -0.193822
# 1943   0.7111  5.237010e+09  1.7997  1.4751  ... -0.044895 -0.012409
#
#            SR_R  l1_TURN_R    lnPD_R  SENT_INDEX_R  SENT_INDEX_EX  \
# 0     15.745780  -0.003943 -0.208500     -1.191905      -0.571980
# 1     15.745780  -0.004333 -0.208500     -1.182604      -0.598652
# 2     15.745780  -0.003813 -0.208500     -1.175354      -0.623006
# 3     15.745780  -0.003643 -0.208500     -1.172984      -0.644795
# 4     15.745780  -0.004513 -0.208500     -1.185114      -0.664723
# ...         ...        ...       ...           ...            ...
# 1939  -2.832969   0.001832  0.097983      0.390557       1.170102
# 1940  -2.832969   0.000582  0.097983      1.186737       1.127746
# 1941  -2.832969   0.000302  0.097983      0.013389       1.149856
# 1942  -2.832969   0.000072  0.097983      0.972127       1.079838
# 1943  -2.832969   0.000102  0.097983      0.720920       1.088991
#
#       SENT_INDEX_DEX  SENT_INDEX_R_EX  SENT_INDEX_R_DEX
# 0          -0.588495        -0.435412         -0.451046
# 1          -0.588830        -0.502679         -0.452930
# 2          -0.589509        -0.563137         -0.455863
# 3          -0.590505        -0.617575         -0.459753
# 4          -0.591815        -0.666961         -0.464538
# ...              ...              ...               ...
# 1939        1.302731         0.960139          1.050876
# 1940        1.298598         0.909492          1.046500
# 1941        1.293518         0.934144          1.040757
# 1942        1.288670         0.852272          1.035358
# 1943        1.283711         0.862929          1.029868
#
# [1944 rows x 71 columns]

# %% [markdown]
# ## 第二章 情绪指标体系

# %% [markdown]
# ### 分析师情绪

# %%
# @formatter:off

# %%
# %%stata -d df_is -force  -qui -gw 9in -gh 5in
# /*{*/
# //模型设定
# encode ts_code,gen(id)
# ge dt = date(trade_date, "YMD")
# format dt %tdCCYYNNDD
# xtset id dt
#
# //模型设定 绘图
# twoway (tsline CON_NP, yaxis(1) lpattern(solid)) ///
#     (tsline opt_profit, yaxis(2) lpattern(tight_dot)) if (time<=1900), ///
#     ytitle(Profit ,axis(1)) ytitle("Bias (%)",axis(2))  ///
#     xtitle("") legend(off) scheme(sj) xsize(10) ylabel(, nogrid) ///
#     xlabel(, labgap(medium)) ///
#     name(ana_sent,replace) title("000985.SH")

# %%
# %%stata -nogr -qui
# /*{*/
# // 绘图
# foreach var in SENT_INDEX SENT_INDEX_R SENT_INDEX_R_EX  {
#     twoway (line `var' dt, yaxis(1) lpattern(solid)  lcolor(gs12)) ///
#     (line close dt, yaxis(2) lpattern(solid) lcolor(gs4)) , ///
#     ytitle("Sent Index" ,axis(1)) ytitle("Share Index",axis(2))  ///
#     xtitle("") legend(off) scheme(sj) xsize(10) ylabel(, nogrid) ///
#     xlabel(, labgap(medium)) ///
#     name(code1_`var',replace) title("`var'")
# }

# %% [markdown]
# ### 金融市场情绪

# %%
# %%stata -gw 9in -gh 5in
# graph combine code1_SENT_INDEX code1_SENT_INDEX_R code1_SENT_INDEX_R_EX , cols(1) name(c1,replace) scale(0.4) scheme(sj)

# %% [markdown]
# ### 情绪指标相关系数矩阵

# %% [markdown]
# 显著性检验

# %%
# %%stata -d df_is -force
# /*{*/
# //清除估计结果
# est clear
#
# //生成时间变量 (已排序)
# ge date=_n
# tsset date
#
# //定义待对比的指标
# local independent_vars "close_chg img_neg tex_neg SENT_INDEX_EX SENT_INDEX_R_EX opt_profit"
# pwcorr `independent_vars', sig
# mat p_values = r(sig)
# esttab mat(p_values)  using outputs/sentindex_pwcorr.csv,r nomtitle type
# /*}*/
# Out:
# . /*{*/
# . //清除估计结果
# . est clear
#
# .
# . //生成时间变量 (已排序)
# . ge date=_n
#
# . tsset date
#
# Time variable: date, 1 to 1944
#         Delta: 1 unit
#
# .
# . //定义待对比的指标
# . local independent_vars "close_chg img_neg tex_neg SENT_INDEX_EX SENT_INDEX_R_
# > EX opt_profit"
#
# . pwcorr `independent_vars', sig
#
#              | close_~g  img_neg  tex_neg SEN~X_EX SEN~R_EX opt_pr~t
# -------------+------------------------------------------------------
#    close_chg |   1.0000
#              |
#              |
#      img_neg |   0.0106   1.0000
#              |   0.6414
#              |
#      tex_neg |  -0.0090   0.0485   1.0000
#              |   0.6902   0.0324
#              |
# SENT_IN~X_EX |  -0.0010   0.1806   0.0394   1.0000
#              |   0.9635   0.0000   0.0827
#              |
# SENT_IN~R_EX |  -0.0010   0.1723   0.0501   0.9711   1.0000
#              |   0.9648   0.0000   0.0272   0.0000
#              |
#   opt_profit |  -0.0251  -0.0342  -0.0822  -0.5391  -0.6060   1.0000
#              |   0.2690   0.1312   0.0003   0.0000   0.0000
#              |
#
# . mat p_values = r(sig)
#
# . esttab mat(p_values)  using outputs/sentindex_pwcorr.csv,r nomtitle type
#
# ="",="close_chg",="img_neg",="tex_neg",="SENT_INDEX_EX",="SENT_INDEX_R_EX",="op
# > t_profit"
# ="close_chg",=".",=".6414346",=".6901737",=".963455",=".9648337",=".2689639"
# ="img_neg",=".6414346",=".",=".0324476",="1.04e-15",="2.00e-14",=".1311724"
# ="tex_neg",=".6901737",=".0324476",=".",=".0826649",=".027216",=".0002849"
# ="SENT_INDEX_EX",=".963455",="1.04e-15",=".0826649",=".",="0",="5.1e-147"
# ="SENT_INDEX_R_EX",=".9648337",="2.00e-14",=".027216",="0",=".",="3.0e-195"
# ="opt_profit",=".2689639",=".1311724",=".0002849",="5.1e-147",="3.0e-195",="."
# (output written to outputs/sentindex_pwcorr.csv)
#
# . /*}*/
# .

# %%
# @formatter:on
import re
# 处理滞后时序数据
df_corr = pd.read_csv('outputs/sentindex_pwcorr.csv').replace({'=': '', '"': '', }, regex=True)
df_corr = df_corr.drop(df_corr.columns[0], axis=1)
df_corr = df_corr.applymap(lambda x: re.sub(r'^\.$', '1', str(x)))
df_corr.astype('float64').to_csv('outputs/sentindex_pwcorr_t.csv')

df = df_is[['close_chg', 'img_neg', 'tex_neg', 'SENT_INDEX_EX', 'SENT_INDEX_R_EX', 'opt_profit']].copy()
df['close_chg'] = df['close_chg'].shift(-1)
df.rename(
columns={'close_chg': 'Return_t+1', 'img_neg': 'Media_img', 'tex_neg': 'Media_text', 'SENT_INDEX_EX': 'PCA', 'SENT_INDEX_R_EX': 'PCA_R',
'opt_profit': 'Analyst'}, inplace=True)
df
# Out:
#       Return_t+1  Media_img  Media_text       PCA     PCA_R    Analyst
# 0      -0.907044   0.000000    0.000000 -0.571980 -0.435412  15.279813
# 1      -2.471193   0.000000    0.333333 -0.598652 -0.502679  15.279489
# 2       0.385618   0.285714    0.142857 -0.623006 -0.563137  15.239177
# 3       0.416474   0.000000    0.333333 -0.644795 -0.617575  15.123971
# 4      -1.143739   0.333333    0.000000 -0.664723 -0.666961  15.001799
# ...          ...        ...         ...       ...       ...        ...
# 1939    0.716572   0.220339    0.152542  1.170102  0.960139  12.253340
# 1940   -0.910999   0.047619    0.238095  1.127746  0.909492  12.230290
# 1941    0.848972   0.250000    0.350000  1.149856  0.934144  12.098412
# 1942    0.581746   0.388889    0.277778  1.079838  0.852272  12.035713
# 1943         NaN   0.142857    0.047619  1.088991  0.862929  11.952399
#
# [1944 rows x 6 columns]

# %%
import seaborn as sns
from matplotlib.colors import BoundaryNorm
# 计算相关系数矩阵
corr_matrix = df.corr().copy()

# 显著性矩阵
p_values = pd.read_csv('outputs/sentindex_pwcorr_t.csv').drop(columns=['Unnamed: 0']).to_numpy()

# 将下三角矩阵的元素替换为NaN
p_values = np.tril(p_values, k=-1)
p_values[p_values == 0] = np.nan

# 将p值矩阵转换为数据框
p_values = pd.DataFrame(p_values, index=corr_matrix.index, columns=corr_matrix.columns)

# 定义颜色映射和范围
colors = ['#525252', '#7B7B7B', '#ADAAAA', '#FFFFFF', ]
bounds = [0, 0.01, 0.05, 0.1, 0.2]
cmap = sns.color_palette(colors, n_colors=len(bounds) - 1)
norm = BoundaryNorm(bounds, len(bounds) - 1)

# 设置图像大小和dpi
plt.figure(figsize=(15, 10), dpi=200)

# 绘制热力图
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', mask=p_values.notnull(), alpha=0.9, cbar=False,
cbar_kws={"label": "Person"}, annot_kws={"fontsize": 14})
sns.heatmap(p_values, annot=True, fmt='.2f', cmap=cmap, norm=norm, mask=p_values.isnull(), alpha=0.9, cbar=True,
cbar_kws={"label": "P -Value"}, annot_kws={"fontsize": 14})
plt.show()

# %% [markdown]
# ### 样本内回归和样本外预测

# %%
# @formatter:off

# %%
# %%stata -d df_is -force
# /*{*/
# //清除估计结果
# est clear
#
# //生成时间变量 (已排序)
# ge date=_n
# tsset date
#
# // 划分训练集和测试集
# ge byte in_train = (date < 1944*0.8)
# ge byte in_test = (date >= 1944*0.8)
#
# //计算测试集中因变量的均值
# egen mean_close_chg = mean(close_chg) if in_test
#
# //计算实际值与均值之间的平方差异的总和
# egen sum_sq_diff_mean = total((close_chg - mean_close_chg)^2) if in_test
#
# //计算基准模型预测误差
# ge error_benchmark = close_chg - mean_close_chg if in_test
#
# //定义待对比的指标
# local independent_vars "img_neg tex_neg SENT_INDEX_EX SENT_INDEX_R_EX opt_profit"
#
# //循环
# foreach var of local independent_vars{
#
#         //1.样本外OOS R2
#
#         //使用训练集进行线性回归建模 滞后1期
#         eststo `var': reg close_chg l.`var' if in_train
#         scalar coef = e(b)[1, 1]
#         estadd scalar coef
#         scalar tstat = e(b)[1, 1]/(sqrt(e(V)[1, 1]))
#         estadd scalar tstat
#
#         //进行样本外预测,线性预测值
#         predict pred_`var' if in_test
#
#         //计算MSPE
#         egen mspe_`var' = mean((close_chg - pred_`var')^2) if in_test /*{*/
#         qui sum mspe_`var' if in_test
#         scalar mspe = r(mean)
#         estadd scalar mspe
#
#         //计算实际值与预测值之间的平方差异的总和
#         egen sum_sq_diff_pred_`var' = total((close_chg - pred_`var')^2) if in_test
#
#         //计算样本外 R-squared (OOS R2)
#         ge oos_r2_`var' = 1 - (sum_sq_diff_pred_`var' / sum_sq_diff_mean) if in_test
#         qui sum oos_r2_`var' if in_test
#         scalar oos_r2 = r(mean)
#         estadd scalar oos_r2
#
#         //2.CW测试
#
#         // 计算预测误差
#         ge error_`var' = close_chg - pred_`var' if in_test
#
#         //计算误差差值(Error differences)
#         ge error_diff_`var' = error_`var'^2 - error_benchmark^2 if in_test
#
#         //使用误差差值执行线性回归
#         reg error_diff_`var' l.error_diff_`var' if in_test
#
# }
# Out:
# . /*{*/
# . //清除估计结果
# . est clear
#
# .
# . //生成时间变量 (已排序)
# . ge date=_n
#
# . tsset date
#
# Time variable: date, 1 to 1944
#         Delta: 1 unit
#
# .
# . // 划分训练集和测试集
# . ge byte in_train = (date < 1944*0.8)
#
# . ge byte in_test = (date >= 1944*0.8)
#
# .
# . //计算测试集中因变量的均值
# . egen mean_close_chg = mean(close_chg) if in_test
# (1,555 missing values generated)
#
# .
# . //计算实际值与均值之间的平方差异的总和
# . egen sum_sq_diff_mean = total((close_chg - mean_close_chg)^2) if in_test
# (1,555 missing values generated)
#
# .
# . //计算基准模型预测误差
# . ge error_benchmark = close_chg - mean_close_chg if in_test
# (1,555 missing values generated)
#
# .
# . //定义待对比的指标
# . local independent_vars "img_neg tex_neg SENT_INDEX_EX SENT_INDEX_R_EX opt_pro
# > fit"
#
# .
# . //循环
# . foreach var of local independent_vars{
#   2.
# .         //1.样本外OOS R2
# .
# .         //使用训练集进行线性回归建模 滞后1期
# .         eststo `var': reg close_chg l.`var' if in_train
#   3.         scalar coef = e(b)[1, 1]
#   4.         estadd scalar coef
#   5.         scalar tstat = e(b)[1, 1]/(sqrt(e(V)[1, 1]))
#   6.         estadd scalar tstat
#   7.
# .         //进行样本外预测,线性预测值
# .         predict pred_`var' if in_test
#   8.
# .         //计算MSPE
# .         egen mspe_`var' = mean((close_chg - pred_`var')^2) if in_test /*{*/
#   9.         qui sum mspe_`var' if in_test
#  10.         scalar mspe = r(mean)
#  11.         estadd scalar mspe
#  12.
# .         //计算实际值与预测值之间的平方差异的总和
# .         egen sum_sq_diff_pred_`var' = total((close_chg - pred_`var')^2) if in
# > _test
#  13.
# .         //计算样本外 R-squared (OOS R2)
# .         ge oos_r2_`var' = 1 - (sum_sq_diff_pred_`var' / sum_sq_diff_mean) if
# > in_test
#  14.         qui sum oos_r2_`var' if in_test
#  15.         scalar oos_r2 = r(mean)
#  16.         estadd scalar oos_r2
#  17.
# .         //2.CW测试
# .
# .         // 计算预测误差
# .         ge error_`var' = close_chg - pred_`var' if in_test
#  18.
# .         //计算误差差值(Error differences)
# .         ge error_diff_`var' = error_`var'^2 - error_benchmark^2 if in_test
#  19.
# .         //使用误差差值执行线性回归
# .         reg error_diff_`var' l.error_diff_`var' if in_test
#  20.
# . }
#
#       Source |       SS           df       MS      Number of obs   =     1,554
# -------------+----------------------------------   F(1, 1552)      =      4.06
#        Model |  10.0531181         1  10.0531181   Prob > F        =    0.0440
#     Residual |  3839.95823     1,552  2.47419989   R-squared       =    0.0026
# -------------+----------------------------------   Adj R-squared   =    0.0020
#        Total |  3850.01135     1,553  2.47908007   Root MSE        =     1.573
#
# ------------------------------------------------------------------------------
#    close_chg | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#      img_neg |
#          L1. |  -.5188889   .2574195    -2.02   0.044    -1.023816   -.0139622
#              |
#        _cons |   .1376719   .0629489     2.19   0.029      .014198    .2611457
# ------------------------------------------------------------------------------
#
# added scalar:
#                e(coef) =  -.51888889
#
# added scalar:
#               e(tstat) =  -2.015733
# (option xb assumed; fitted values)
# (1,555 missing values generated)
# (1,555 missing values generated)
#
# added scalar:
#                e(mspe) =  1.3063207
# (1,555 missing values generated)
# (1,555 missing values generated)
#
# added scalar:
#              e(oos_r2) =  .00359771
# (1,555 missing values generated)
# (1,555 missing values generated)
#
#       Source |       SS           df       MS      Number of obs   =       388
# -------------+----------------------------------   F(1, 386)       =      1.87
#        Model |  .069400608         1  .069400608   Prob > F        =    0.1720
#     Residual |  14.3092141       386  .037070503   R-squared       =    0.0048
# -------------+----------------------------------   Adj R-squared   =    0.0022
#        Total |  14.3786147       387  .037154043   Root MSE        =    .19254
#
# ------------------------------------------------------------------------------
# error_diff~g | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# error_diff~g |
#          L1. |   .0695479   .0508296     1.37   0.172    -.0303896    .1694854
#              |
#        _cons |  -.0043576   .0097781    -0.45   0.656    -.0235827    .0148674
# ------------------------------------------------------------------------------
#
#       Source |       SS           df       MS      Number of obs   =     1,554
# -------------+----------------------------------   F(1, 1552)      =      0.55
#        Model |  1.36951801         1  1.36951801   Prob > F        =    0.4575
#     Residual |  3848.64183     1,552    2.479795   R-squared       =    0.0004
# -------------+----------------------------------   Adj R-squared   =   -0.0003
#        Total |  3850.01135     1,553  2.47908007   Root MSE        =    1.5747
#
# ------------------------------------------------------------------------------
#    close_chg | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#      tex_neg |
#          L1. |   .1794687   .2414976     0.74   0.458    -.2942273    .6531647
#              |
#        _cons |     .00514   .0611349     0.08   0.933    -.1147758    .1250558
# ------------------------------------------------------------------------------
#
# added scalar:
#                e(coef) =  .17946873
#
# added scalar:
#               e(tstat) =  .74314915
# (option xb assumed; fitted values)
# (1,555 missing values generated)
# (1,555 missing values generated)
#
# added scalar:
#                e(mspe) =  1.3155184
# (1,555 missing values generated)
# (1,555 missing values generated)
#
# added scalar:
#              e(oos_r2) =  -.00341789
# (1,555 missing values generated)
# (1,555 missing values generated)
#
#       Source |       SS           df       MS      Number of obs   =       388
# -------------+----------------------------------   F(1, 386)       =      1.77
#        Model |  .019888239         1  .019888239   Prob > F        =    0.1846
#     Residual |  4.34639191       386  .011260083   R-squared       =    0.0046
# -------------+----------------------------------   Adj R-squared   =    0.0020
#        Total |  4.36628015       387  .011282378   Root MSE        =    .10611
#
# ------------------------------------------------------------------------------
# er~f_tex_neg | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# er~f_tex_neg |
#          L1. |   .0674949   .0507859     1.33   0.185    -.0323568    .1673465
#              |
#        _cons |   .0042063   .0053918     0.78   0.436    -.0063946    .0148072
# ------------------------------------------------------------------------------
#
#       Source |       SS           df       MS      Number of obs   =     1,554
# -------------+----------------------------------   F(1, 1552)      =      0.09
#        Model |  .226775009         1  .226775009   Prob > F        =    0.7624
#     Residual |  3849.78458     1,552   2.4805313   R-squared       =    0.0001
# -------------+----------------------------------   Adj R-squared   =   -0.0006
#        Total |  3850.01135     1,553  2.47908007   Root MSE        =     1.575
#
# ------------------------------------------------------------------------------
#    close_chg | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# SENT_IN~X_EX |
#          L1. |  -.0237724   .0786226    -0.30   0.762    -.1779902    .1304454
#              |
#        _cons |   .0368862   .0408999     0.90   0.367    -.0433388    .1171111
# ------------------------------------------------------------------------------
#
# added scalar:
#                e(coef) =  -.02377238
#
# added scalar:
#               e(tstat) =  -.30236063
# (option xb assumed; fitted values)
# (1,555 missing values generated)
# (1,555 missing values generated)
#
# added scalar:
#                e(mspe) =  1.3160586
# (1,555 missing values generated)
# (1,555 missing values generated)
#
# added scalar:
#              e(oos_r2) =  -.00382994
# (1,555 missing values generated)
# (1,555 missing values generated)
#
#       Source |       SS           df       MS      Number of obs   =       388
# -------------+----------------------------------   F(1, 386)       =      1.73
#        Model |  .057270166         1  .057270166   Prob > F        =    0.1891
#     Residual |  12.7749233       386  .033095656   R-squared       =    0.0045
# -------------+----------------------------------   Adj R-squared   =    0.0019
#        Total |  12.8321934       387  .033158123   Root MSE        =    .18192
#
# ------------------------------------------------------------------------------
# error_diff~X | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# error_diff~X |
#          L1. |   .0668194   .0507953     1.32   0.189    -.0330508    .1666895
#              |
#        _cons |   .0047241    .009239     0.51   0.609    -.0134409    .0228891
# ------------------------------------------------------------------------------
#
#       Source |       SS           df       MS      Number of obs   =     1,554
# -------------+----------------------------------   F(1, 1552)      =      0.01
#        Model |  .019633174         1  .019633174   Prob > F        =    0.9291
#     Residual |  3849.99172     1,552  2.48066477   R-squared       =    0.0000
# -------------+----------------------------------   Adj R-squared   =   -0.0006
#        Total |  3850.01135     1,553  2.47908007   Root MSE        =     1.575
#
# ------------------------------------------------------------------------------
#    close_chg | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# SENT_IN~R_EX |
#          L1. |  -.0066928   .0752307    -0.09   0.929    -.1542572    .1408717
#              |
#        _cons |   .0381525   .0428577     0.89   0.373    -.0459127    .1222177
# ------------------------------------------------------------------------------
#
# added scalar:
#                e(coef) =  -.00669277
#
# added scalar:
#               e(tstat) =  -.08896337
# (option xb assumed; fitted values)
# (1,555 missing values generated)
# (1,555 missing values generated)
#
# added scalar:
#                e(mspe) =  1.3134301
# (1,555 missing values generated)
# (1,555 missing values generated)
#
# added scalar:
#              e(oos_r2) =  -.00182503
# (1,555 missing values generated)
# (1,555 missing values generated)
#
#       Source |       SS           df       MS      Number of obs   =       388
# -------------+----------------------------------   F(1, 386)       =      1.62
#        Model |   .02532519         1   .02532519   Prob > F        =    0.2039
#     Residual |   6.0351879       386  .015635202   R-squared       =    0.0042
# -------------+----------------------------------   Adj R-squared   =    0.0016
#        Total |  6.06051309       387  .015660241   Root MSE        =    .12504
#
# ------------------------------------------------------------------------------
# error_d~R_EX | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# error_d~R_EX |
#          L1. |   .0646571   .0508033     1.27   0.204    -.0352287     .164543
#              |
#        _cons |   .0022644    .006349     0.36   0.722    -.0102186    .0147474
# ------------------------------------------------------------------------------
#
#       Source |       SS           df       MS      Number of obs   =     1,554
# -------------+----------------------------------   F(1, 1552)      =      1.19
#        Model |  2.95521086         1  2.95521086   Prob > F        =    0.2751
#     Residual |  3847.05614     1,552  2.47877329   R-squared       =    0.0008
# -------------+----------------------------------   Adj R-squared   =    0.0001
#        Total |  3850.01135     1,553  2.47908007   Root MSE        =    1.5744
#
# ------------------------------------------------------------------------------
#    close_chg | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#   opt_profit |
#          L1. |  -.0071351   .0065346    -1.09   0.275    -.0199527    .0056826
#              |
#        _cons |   .1521059    .110566     1.38   0.169    -.0647686    .3689805
# ------------------------------------------------------------------------------
#
# added scalar:
#                e(coef) =  -.00713506
#
# added scalar:
#               e(tstat) =  -1.0918823
# (option xb assumed; fitted values)
# (1,555 missing values generated)
# (1,555 missing values generated)
#
# added scalar:
#                e(mspe) =  1.3124692
# (1,555 missing values generated)
# (1,555 missing values generated)
#
# added scalar:
#              e(oos_r2) =  -.00109218
# (1,555 missing values generated)
# (1,555 missing values generated)
#
#       Source |       SS           df       MS      Number of obs   =       388
# -------------+----------------------------------   F(1, 386)       =      6.24
#        Model |  .016516973         1  .016516973   Prob > F        =    0.0129
#     Residual |  1.02138317       386   .00264607   R-squared       =    0.0159
# -------------+----------------------------------   Adj R-squared   =    0.0134
#        Total |  1.03790014       387  .002681913   Root MSE        =    .05144
#
# ------------------------------------------------------------------------------
# error_diff~t | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# error_diff~t |
#          L1. |   .1261671   .0504989     2.50   0.013     .0268798    .2254543
#              |
#        _cons |   .0012616   .0026124     0.48   0.629    -.0038747    .0063979
# ------------------------------------------------------------------------------
#
# .
# .

# %%
# %%stata
# ereturn list
# esttab ,star(* 0.1 ** 0.05 *** 0.01)  scalars(coef tstat r2 mspe oos_r2)
# mat R = r(stats)'
# esttab mat(R) using outputs/sentindex_compare,r nomtitle nogaps compress
# Out:
# . ereturn list
#
# scalars:
#                   e(N) =  388
#                e(df_m) =  1
#                e(df_r) =  386
#                   e(F) =  6.242076148190041
#                  e(r2) =  .0159138361939318
#                e(rmse) =  .0514399688162567
#                 e(mss) =  .0165169728791956
#                 e(rss) =  1.021383171241538
#                e(r2_a) =  .0133643901737089
#                  e(ll) =  601.782279771622
#                e(ll_0) =  598.6701665131624
#                e(rank) =  2
#
# macros:
#             e(cmdline) : "regress error_diff_opt_profit l.error_diff_opt_pr.."
#               e(title) : "Linear regression"
#           e(marginsok) : "XB default"
#                 e(vce) : "ols"
#              e(depvar) : "error_diff_opt_profit"
#                 e(cmd) : "regress"
#          e(properties) : "b V"
#             e(predict) : "regres_p"
#               e(model) : "ols"
#           e(estat_cmd) : "regress_estat"
#
# matrices:
#                   e(b) :  1 x 2
#                   e(V) :  2 x 2
#                e(beta) :  1 x 1
#
# functions:
#              e(sample)
#
# . esttab ,star(* 0.1 ** 0.05 *** 0.01)  scalars(coef tstat r2 mspe oos_r2)
# (tabulating estimates stored by eststo; specify "." to tabulate the active resu
# > lts)
#
# -------------------------------------------------------------------------------
# > -------------
#                       (1)             (2)             (3)             (4)
# >        (5)
#                 close_chg       close_chg       close_chg       close_chg
# >  close_chg
# -------------------------------------------------------------------------------
# > -------------
# L.img_neg          -0.519**
# >
#                   (-2.02)
# >
#
# L.tex_neg                           0.179
# >
#                                    (0.74)
# >
#
# L.SENT_~X_EX                                      -0.0238
# >
#                                                   (-0.30)
# >
#
# L.SENT_~R_EX                                                     -0.00669
# >
#                                                                   (-0.09)
# >
#
# L.opt_profit
# >   -0.00714
#
# >    (-1.09)
#
# _cons               0.138**       0.00514          0.0369          0.0382
# >      0.152
#                    (2.19)          (0.08)          (0.90)          (0.89)
# >     (1.38)
# -------------------------------------------------------------------------------
# > -------------
# N                    1554            1554            1554            1554
# >       1554
# coef               -0.519           0.179         -0.0238        -0.00669
# >   -0.00714
# tstat              -2.016           0.743          -0.302         -0.0890
# >     -1.092
# r2                0.00261        0.000356       0.0000589      0.00000510
# >   0.000768
# mspe                1.306           1.316           1.316           1.313
# >      1.312
# oos_r2            0.00360        -0.00342        -0.00383        -0.00183
# >   -0.00109
# -------------------------------------------------------------------------------
# > -------------
# t statistics in parentheses
# * p<0.1, ** p<0.05, *** p<0.01
#
# . mat R = r(stats)'
#
# . esttab mat(R) using outputs/sentindex_compare,r nomtitle nogaps compress
# (output written to outputs/sentindex_compare.txt)
#
# .

# %% [markdown]
# ## 第三章 情绪对股票市场影响的实证研究

# %% [markdown]
# ### 媒体情绪对股票市场的影响

# %%
# %%stata -d df_is -force -gw 9in -gh 5in
# /*{*/
# //时间设定
# tsset time
# est clear
#
# //VAR回归
# eststo: var close_chg img_neg close_chg_s, lags(1/5) exog(trade_year trade_month)
# estadd local Month "Yes", replace
# estadd local Weekday "Yes", replace
#
# // 脉冲响应曲线
# /*{*/
# irf creat var, set(outputs/var_img ,replace) step(5)
# irf graph oirf, impulse(img_neg) response(close_chg) lstep(0) ustep(5)  name(var_img,replace) ///
# byopts(note("")) byopts(legend(off)) xtitle(, size(small) margin(zero)) ///
# ysc(r(-0.15,0.15)) yline(0) ylabel(#2) ytitle(return, size(small) margin(zero)) scheme(sj)
#
# /*{*/
# //输出
# esttab , keep(close_chg:L*.img_neg) ///
# star(* 0.1 ** 0.05 *** 0.01) ///
# stats( Month Weekday  r2_1 N, fmt(%3s %3s %12.4f %12.0f)) b(%12.4f) nogap
# Out:
# . /*{*/
# . //时间设定
# . tsset time
#
# Time variable: time, 1 to 1944
#         Delta: 1 unit
#
# . est clear
#
# .
# . //VAR回归
# . eststo: var close_chg img_neg close_chg_s, lags(1/5) exog(trade_year trade_mo
# > nth)
# note: trade_year omitted because of collinearity.
#
# Vector autoregression
#
# Sample: 6 thru 1944                             Number of obs     =      1,939
# Log likelihood =  -8382.236                     AIC               =   8.698541
# FPE            =   1.203112                     HQIC              =   8.752418
# Det(Sigma_ml)  =   1.141457                     SBIC              =   8.845042
#
# Equation           Parms      RMSE     R-sq      chi2     P>chi2
# ----------------------------------------------------------------
# close_chg            17     1.48995   0.0198   39.25336   0.0010
# img_neg              17     .143133   0.0442   89.64701   0.0000
# close_chg_s          17     5.38798   0.1857   442.0808   0.0000
# ----------------------------------------------------------------
#
# ------------------------------------------------------------------------------
#              | Coefficient  Std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# close_chg    |
#    close_chg |
#          L1. |   .0706612   .0240648     2.94   0.003      .023495    .1178273
#          L2. |    -.01194   .0241357    -0.49   0.621     -.059245    .0353651
#          L3. |   .0056127   .0242596     0.23   0.817    -.0419353    .0531607
#          L4. |   .0412967   .0241357     1.71   0.087    -.0060085    .0886018
#          L5. |  -.0278187   .0239823    -1.16   0.246    -.0748232    .0191858
#              |
#      img_neg |
#          L1. |  -.6280265   .2361761    -2.66   0.008    -1.090923   -.1651299
#          L2. |   .0860886   .2370065     0.36   0.716    -.3784357    .5506128
#          L3. |   .0414787    .236392     0.18   0.861    -.4218411    .5047985
#          L4. |   .0387585   .2368429     0.16   0.870    -.4254451    .5029621
#          L5. |  -.4756329   .2363218    -2.01   0.044    -.9388152   -.0124506
#              |
#  close_chg_s |
#          L1. |   .0086515   .0066292     1.31   0.192    -.0043414    .0216445
#          L2. |   .0025188   .0065749     0.38   0.702    -.0103678    .0154053
#          L3. |   -.007932   .0065289    -1.21   0.224    -.0207284    .0048643
#          L4. |   .0011383   .0064882     0.18   0.861    -.0115784     .013855
#          L5. |  -.0239242   .0065016    -3.68   0.000    -.0366672   -.0111813
#              |
#  trade_month |  -.0000505   .0001586    -0.32   0.750    -.0003613    .0002602
#        _cons |   10.47119   31.96557     0.33   0.743    -52.18019    73.12256
# -------------+----------------------------------------------------------------
# img_neg      |
#    close_chg |
#          L1. |   -.000112   .0023118    -0.05   0.961     -.004643    .0044191
#          L2. |    .001249   .0023186     0.54   0.590    -.0032954    .0057934
#          L3. |   .0031957   .0023305     1.37   0.170     -.001372    .0077635
#          L4. |  -.0004075   .0023186    -0.18   0.861    -.0049519     .004137
#          L5. |   .0021925   .0023039     0.95   0.341     -.002323     .006708
#              |
#      img_neg |
#          L1. |   .0577086   .0226885     2.54   0.011       .01324    .1021773
#          L2. |   .0299805   .0227683     1.32   0.188    -.0146445    .0746055
#          L3. |   .0728857   .0227092     3.21   0.001     .0283764     .117395
#          L4. |  -.0148086   .0227526    -0.65   0.515    -.0594028    .0297857
#          L5. |   .0167411   .0227025     0.74   0.461     -.027755    .0612371
#              |
#  close_chg_s |
#          L1. |  -.0009922   .0006368    -1.56   0.119    -.0022404     .000256
#          L2. |  -.0004877   .0006316    -0.77   0.440    -.0017257    .0007502
#          L3. |   .0000101   .0006272     0.02   0.987    -.0012192    .0012394
#          L4. |  -.0001218   .0006233    -0.20   0.845    -.0013434    .0010999
#          L5. |   .0006938   .0006246     1.11   0.267    -.0005303     .001918
#              |
#  trade_month |    .000088   .0000152     5.78   0.000     .0000582    .0001179
#        _cons |  -17.59353   3.070807    -5.73   0.000     -23.6122   -11.57486
# -------------+----------------------------------------------------------------
# close_chg_s  |
#    close_chg |
#          L1. |  -.3264215   .0870236    -3.75   0.000    -.4969846   -.1558585
#          L2. |  -.3976085   .0872799    -4.56   0.000    -.5686739    -.226543
#          L3. |  -.0905077    .087728    -1.03   0.302    -.2624515    .0814361
#          L4. |  -.1608728     .08728    -1.84   0.065    -.3319385    .0101929
#          L5. |   .1939262   .0867253     2.24   0.025     .0239477    .3639047
#              |
#      img_neg |
#          L1. |   .3540881    .854064     0.41   0.678    -1.319847    2.028023
#          L2. |   .6604982   .8570671     0.77   0.441    -1.019322    2.340319
#          L3. |   .5382471   .8548448     0.63   0.529    -1.137218    2.213712
#          L4. |  -1.319905   .8564754    -1.54   0.123    -2.998566    .3587557
#          L5. |    1.71568   .8545911     2.01   0.045     .0407126    3.390648
#              |
#  close_chg_s |
#          L1. |    .058167   .0239725     2.43   0.015     .0111817    .1051523
#          L2. |   .1128509   .0237762     4.75   0.000     .0662503    .1594515
#          L3. |   .1553893   .0236099     6.58   0.000     .1091148    .2016638
#          L4. |   .1238708   .0234629     5.28   0.000     .0778844    .1698572
#          L5. |   .1221285   .0235113     5.19   0.000     .0760472    .1682098
#              |
#  trade_month |   -.001556   .0005734    -2.71   0.007    -.0026799   -.0004322
#        _cons |   314.5545   115.5945     2.72   0.007      87.9935    541.1155
# ------------------------------------------------------------------------------
# (est1 stored)
#
# . estadd local Month "Yes", replace
#
# added macro:
#               e(Month) : "Yes"
#
# . estadd local Weekday "Yes", replace
#
# added macro:
#             e(Weekday) : "Yes"
#
# .
# . // 脉冲响应曲线
# . /*{*/
# . irf creat var, set(outputs/var_img ,replace) step(5)
# (file outputs/var_img.irf created)
# (file outputs/var_img.irf now active)
# (file outputs/var_img.irf updated)
#
# . irf graph oirf, impulse(img_neg) response(close_chg) lstep(0) ustep(5)  name(
# > var_img,replace) ///
# > byopts(note("")) byopts(legend(off)) xtitle(, size(small) margin(zero)) ///
# > ysc(r(-0.15,0.15)) yline(0) ylabel(#2) ytitle(return, size(small) margin(zero
# > )) scheme(sj)
#
# .
# . /*{*/
# . //输出
# . esttab , keep(close_chg:L*.img_neg) ///
# > star(* 0.1 ** 0.05 *** 0.01) ///
# > stats( Month Weekday  r2_1 N, fmt(%3s %3s %12.4f %12.0f)) b(%12.4f) nogap
#
# ----------------------------
#                       (1)
#                 close_chg
# ----------------------------
# close_chg
# L.img_neg         -0.6280***
#                   (-2.66)
# L2.img_neg         0.0861
#                    (0.36)
# L3.img_neg         0.0415
#                    (0.18)
# L4.img_neg         0.0388
#                    (0.16)
# L5.img_neg        -0.4756**
#                   (-2.01)
# ----------------------------
# Month                 Yes
# Weekday               Yes
# r2_1               0.0198
# N                    1939
# ----------------------------
# t statistics in parentheses
# * p<0.1, ** p<0.05, *** p<0.01
#
# .

# %% [markdown]
# ### 媒体情绪对分析师情绪的影响

# %%
# %%stata -d df_is -force
#
# //声明面板数据
# encode ts_code,gen(id)
# xtset id time
#
# //缩尾 ssc install winsor
# winsor2 opt_profit, cut(1 99) by(id) label replace
#
# //变量对数处理
# foreach var in opt_profit total_mv pe_ttm_weight profit_avg {
#     ge ln`var'=ln(`var')
# }
#
# //清除估计结果
# est clear
#
# //图像情绪回归
# rename(img_neg) (media_neg)
# eststo: qui reg lnopt_profit L.media_neg L.lntotal_mv L.lnpe_ttm_weight L.lnprofit_avg i.trade_year,r
# rename(media_neg) (img_neg)
#
# //文本情绪回归
# rename(tex_neg) (media_neg)
# eststo: qui reg lnopt_profit L.media_neg L.lntotal_mv L.lnpe_ttm_weight L.lnprofit_avg i.trade_year,r
# rename(media_neg) (tex_neg)
#
# //增加固定效应
# estadd local Year "Yes" : *
#
# //输出
# esttab using outputs/media_to_analyst,r type ///
# star(* 0.1 ** 0.05 *** 0.01) ///
# keep(*_neg L.* ) ///
# stats( Year r2_a N, fmt(%3s %12.2f %12.0f)) ///
# nogaps compress b(%12.4f) ///
# title("Table MediaSent to AnalystSent Text") ///
#
#
# //图像情绪回归
# Out:
# .
# . //声明面板数据
# . encode ts_code,gen(id)
#
# . xtset id time
#
# Panel variable: id (strongly balanced)
#  Time variable: time, 1 to 1944
#          Delta: 1 unit
#
# .
# . //缩尾 ssc install winsor
# . winsor2 opt_profit, cut(1 99) by(id) label replace
#
# .
# . //变量对数处理
# . foreach var in opt_profit total_mv pe_ttm_weight profit_avg {
#   2.     ge ln`var'=ln(`var')
#   3. }
#
# .
# . //清除估计结果
# . est clear
#
# .
# . //图像情绪回归
# . rename(img_neg) (media_neg)
#
# . eststo: qui reg lnopt_profit L.media_neg L.lntotal_mv L.lnpe_ttm_weight L.lnp
# > rofit_avg i.trade_year,r
# (est1 stored)
#
# . rename(media_neg) (img_neg)
#
# .
# . //文本情绪回归
# . rename(tex_neg) (media_neg)
#
# . eststo: qui reg lnopt_profit L.media_neg L.lntotal_mv L.lnpe_ttm_weight L.lnp
# > rofit_avg i.trade_year,r
# (est2 stored)
#
# . rename(media_neg) (tex_neg)
#
# .
# . //增加固定效应
# . estadd local Year "Yes" : *
#
# .
# . //输出
# . esttab using outputs/media_to_analyst,r type ///
# > star(* 0.1 ** 0.05 *** 0.01) ///
# > keep(*_neg L.* ) ///
# > stats( Year r2_a N, fmt(%3s %12.2f %12.0f)) ///
# > nogaps compress b(%12.4f) ///
# > title("Table MediaSent to AnalystSent Text") ///
# >
#
# Table MediaSent to AnalystSent Text
# ------------------------------------
#                  (1)          (2)
#            lnopt_p~t    lnopt_p~t
# ------------------------------------
# L.media_~g    0.0756***   -0.0746***
#               (2.62)      (-2.76)
# L.lntota~v   -1.2554***   -1.2275***
#              (-7.67)      (-7.54)
# L.lnpe_t~t    0.3851**     0.3639**
#               (2.49)       (2.36)
# L.lnprof~g    1.3168***    1.2905***
#               (6.05)       (5.92)
# ------------------------------------
# Year             Yes          Yes
# r2_a            0.78         0.78
# N               1943         1943
# ------------------------------------
# t statistics in parentheses
# * p<0.1, ** p<0.05, *** p<0.01
# (output written to outputs/media_to_analyst.txt)
#
# .
# . //图像情绪回归
# .
# .

# %% [markdown]
# ### 多群体情绪指标对股票市场的影响

# %%
# @formatter:on

# %%
from keras.models import Model
from keras.layers import Input, Dense
from keras import regularizers
from sklearn.preprocessing import MinMaxScaler
# Normalise
df_is['close_chg_l1'] = df_is['close_chg'].shift(-1)
df_fin=df_is[['img_neg', 'tex_neg', 'SENT_INDEX_R_EX', 'opt_profit']]
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(df_fin)
data_scaled

# Fixed dimensions
input_dim = df_fin.shape[1]  # 8
encoding_dim = 1

# Number of neurons in each Layer [8, 6, 4, 3, ...] of encoders
input_layer = Input(shape=(input_dim,))
encoder_layer_1 = Dense(128, activation="relu", activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder_layer_2 = Dense(128, activation="relu")(encoder_layer_1)
encoder_layer_3 = Dense(encoding_dim, activation="relu")(encoder_layer_2)

# Crear encoder model
encoder = Model(inputs=input_layer, outputs=encoder_layer_3)
# Use the model to predict the factors which sum up the information of interest rates.
encoded_data = pd.DataFrame(encoder.predict(data_scaled))
encoded_data.columns = ['factor_1']

df_en = pd.concat([encoded_data,
                   df_is[['trade_date', 'close_chg', 'img_neg', 'tex_neg', 'SENT_INDEX_R_EX', 'opt_profit', 'trade_year']]],
                  axis=1).astype(dtype={'trade_date': 'str'})
df_en
# Out:
# 61/61 [==============================] - 0s 243us/step
# 2023-06-16 16:08:26.544462: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#       factor_1 trade_date  close_chg   img_neg   tex_neg  SENT_INDEX_R_EX  \
# 0     0.000000   20140102   0.256463  0.000000  0.000000        -0.435412
# 1     0.000000   20140103  -0.907044  0.000000  0.333333        -0.502679
# 2     0.000000   20140106  -2.471193  0.285714  0.142857        -0.563137
# 3     0.000000   20140107   0.385618  0.000000  0.333333        -0.617575
# 4     0.004940   20140108   0.416474  0.333333  0.000000        -0.666961
# ...        ...        ...        ...       ...       ...              ...
# 1939  0.006456   20211227   0.008808  0.220339  0.152542         0.960139
# 1940  0.000000   20211228   0.716572  0.047619  0.238095         0.909492
# 1941  0.008980   20211229  -0.910999  0.250000  0.350000         0.934144
# 1942  0.016142   20211230   0.848972  0.388889  0.277778         0.852272
# 1943  0.000000   20211231   0.581746  0.142857  0.047619         0.862929
#
#       opt_profit  trade_year
# 0      15.279813        2014
# 1      15.279489        2014
# 2      15.239177        2014
# 3      15.123971        2014
# 4      15.001799        2014
# ...          ...         ...
# 1939   12.253340        2021
# 1940   12.230290        2021
# 1941   12.098412        2021
# 1942   12.035713        2021
# 1943   11.952399        2021
#
# [1944 rows x 8 columns]

# %%
df_en=pd.read_csv('outputs/sentindex_fusion.csv').astype(dtype={'trade_date': 'str'})
df_en
# Out:
#       Unnamed: 0  factor_1 trade_date  close_chg   img_neg   tex_neg  \
# 0              0  0.033959   20140102   0.256463  0.000000  0.000000
# 1              1  0.031098   20140103  -0.907044  0.000000  0.333333
# 2              2  0.000000   20140106  -2.471193  0.285714  0.142857
# 3              3  0.030239   20140107   0.385618  0.000000  0.333333
# 4              4  0.000000   20140108   0.416474  0.333333  0.000000
# ...          ...       ...        ...        ...       ...       ...
# 1939        1939  0.037087   20211227   0.008808  0.220339  0.152542
# 1940        1940  0.040093   20211228   0.716572  0.047619  0.238095
# 1941        1941  0.032214   20211229  -0.910999  0.250000  0.350000
# 1942        1942  0.018458   20211230   0.848972  0.388889  0.277778
# 1943        1943  0.053980   20211231   0.581746  0.142857  0.047619
#
#       SENT_INDEX_R_EX  opt_profit  trade_year
# 0           -0.435412   15.279813        2014
# 1           -0.502679   15.279489        2014
# 2           -0.563137   15.239177        2014
# 3           -0.617575   15.123971        2014
# 4           -0.666961   15.001799        2014
# ...               ...         ...         ...
# 1939         0.960139   12.253340        2021
# 1940         0.909492   12.230290        2021
# 1941         0.934144   12.098412        2021
# 1942         0.852272   12.035713        2021
# 1943         0.862929   11.952399        2021
#
# [1944 rows x 9 columns]

# %%
# @formatter:off

# %%
# %%stata -d df_en -force
# /*{*/
# ge time=_n
# tsset time
# ge factor=factor_1
# est clear
#
# rename(img_neg) (SentIndex)
# eststo: qui reg close_chg l(1/5).SentIndex i.trade_year
# rename(SentIndex) (img_neg)
#
# rename(factor) (SentIndex)
# eststo: qui reg close_chg l(1/5).SentIndex i.trade_year
# rename(SentIndex) (factor)
#
# //输出回归结果
# esttab using outputs/encode_to_return ,r type ///
# keep(L*) ///
# star(* 0.1 ** 0.05 *** 0.01) ///
# stats( Year r2_a N, fmt(%3s %12.4f %12.0f)) ///
# title("Table Encode to Return") mtitle("img_neg " "factor ") ///
# nogaps  b(%12.4f)
# Out:
# . /*{*/
# . ge time=_n
#
# . tsset time
#
# Time variable: time, 1 to 1944
#         Delta: 1 unit
#
# . ge factor=factor_1
#
# . est clear
#
# .
# . rename(img_neg) (SentIndex)
#
# . eststo: qui reg close_chg l(1/5).SentIndex i.trade_year
# (est1 stored)
#
# . rename(SentIndex) (img_neg)
#
# .
# . rename(factor) (SentIndex)
#
# . eststo: qui reg close_chg l(1/5).SentIndex i.trade_year
# (est2 stored)
#
# . rename(SentIndex) (factor)
#
# .
# . //输出回归结果
# . esttab using outputs/encode_to_return ,r type ///
# > keep(L*) ///
# > star(* 0.1 ** 0.05 *** 0.01) ///
# > stats( Year r2_a N, fmt(%3s %12.4f %12.0f)) ///
# > title("Table Encode to Return") mtitle("img_neg " "factor ") ///
# > nogaps  b(%12.4f)
#
# Table Encode to Return
# --------------------------------------------
#                       (1)             (2)
#                  img_neg          factor
# --------------------------------------------
# L.SentIndex       -0.5751**        5.2404**
#                   (-2.40)          (2.14)
# L2.SentIndex       0.0783         -3.7209
#                    (0.33)         (-1.49)
# L3.SentIndex       0.0915         -3.0185
#                    (0.38)         (-1.21)
# L4.SentIndex       0.1000         -0.3374
#                    (0.42)         (-0.14)
# L5.SentIndex      -0.4961**        3.3387
#                   (-2.07)          (1.37)
# --------------------------------------------
# Year
# r2_a               0.0033          0.0026
# N                    1939            1939
# --------------------------------------------
# t statistics in parentheses
# * p<0.1, ** p<0.05, *** p<0.01
# (output written to outputs/encode_to_return.txt)
#
# .

# %%
# %%stata -d df_en -force -nogr -qui
# des
# ge dt = date(trade_date, "YMD")
# format dt %tdCCYYNNDD
# ge factor=factor_1
#
# twoway (line img_neg dt, yaxis(1) lpattern(solid)  lcolor(gs6))  , ///
# ytitle("MediaImg SentIndex" ,axis(1))  ///
# xtitle("") legend(off) scheme(sj) xsize(10) ylabel(, nogrid) ///
# xlabel(, labgap(medium)) name(MediaImg,replace)
#
# twoway (line factor dt, yaxis(1) lpattern(solid)  lcolor(gs6))  , ///
# ytitle("Fusion SentIndex" ,axis(1))  ///
# xtitle("") legend(off) scheme(sj) xsize(10) ylabel(, nogrid) ///
# xlabel(, labgap(medium)) name(Fusion,replace)

# %%
# %%stata -gw 9in -gh 5in
# graph combine MediaImg Fusion, cols(1) name(c1,replace) scale(0.6) scheme(sj)

# %% [markdown]
# ## 第四章 情绪投资策略

# %% [markdown]
# ### MA策略

# %%
def ma_strategy(df, factor_list, window_list):
    """
    用均值策略作为买入卖出信号
    :param df: 因子数据
    :param factor_list: 待选决策因子
    :param window_list: 待选决策窗口
    :return:
    """
    out_list = []
    # 循环因子和窗口
    for w in window_list:
        for f in factor_list:
            # 排序
            df = df.sort_values('trade_date')

            # MA均值计算
            df[f'{f}_ma_{w}'] = (df['img_neg'].rolling(w).mean())

            # 形成投资信号
            df[f'{f}_sell_signal_ma_{w}'] = df[f] >= df[f'{f}_ma_{w}']
            df[f'{f}_sell_signal_ma_{w}'] = df[f'{f}_sell_signal_ma_{w}'].shift(1)  # 向前移动一天,使用历史信息

            # 卖空指数操作
            df[f'{f}_return_ma_{w}'] = np.where(df[f'{f}_sell_signal_ma_{w}'], -1 * (df[f'{f}_sell_signal_ma_{w}'] * df['close_chg']),
                                                df['close_chg'])

            # 计算累积市值
            df[f'{f}_mv_ma_{w}'] = ((df[f'{f}_return_ma_{w}'] + 100) / 100).cumprod(axis=0)

            # 输出值列表
            out_list += [f'{f}_mv_ma_{w}', f'{f}_ma_{w}']

    # 去掉空行(MA行)
    df.dropna(axis=0, inplace=True)

    # 对比基准
    df['mv_shareindex'] = ((df['close_chg'] + 100) / 100).cumprod(axis=0)

    return df[['trade_date', 'ts_code', 'mv_shareindex', ] + out_list]


df_res_mv=ma_strategy(df_is, ['img_neg', 'tex_neg', 'SENT_INDEX', 'SENT_INDEX_R'], [5, 10, 15, 20])
df_res_mv
# Out:
#      trade_date    ts_code  mv_shareindex img_neg_mv_ma_5  img_neg_ma_5  \
# 19     20140129  000985.SH       1.007240        0.981319      0.085714
# 20     20140130  000985.SH       0.999213        0.973498      0.085714
# 21     20140207  000985.SH       1.011056        0.985036      0.105714
# 22     20140210  000985.SH       1.037068        1.010379      0.048571
# 23     20140211  000985.SH       1.041429         1.00613      0.048571
# ...         ...        ...            ...             ...           ...
# 1938   20211224  000985.SH       2.062418        4.286312      0.209490
# 1939   20211227  000985.SH       2.062600         4.28669      0.199320
# 1940   20211228  000985.SH       2.077380        4.255973      0.175511
# 1941   20211229  000985.SH       2.058455        4.217201      0.189147
# 1942   20211230  000985.SH       2.075930        4.181398      0.211369
#
#      tex_neg_mv_ma_5  tex_neg_ma_5 SENT_INDEX_mv_ma_5  SENT_INDEX_ma_5  \
# 19          0.996378      0.085714           0.914014         0.085714
# 20          1.004319      0.085714           0.921298         0.085714
# 21          0.992415      0.105714           0.932217         0.105714
# 22          1.017947      0.048571           0.956201         0.048571
# 23          1.013666      0.048571           0.960222         0.048571
# ...              ...           ...                ...              ...
# 1938        0.559758      0.209490           1.172053         0.209490
# 1939        0.559808      0.199320           1.171949         0.199320
# 1940        0.563819      0.175511           1.163552         0.175511
# 1941        0.568956      0.189147           1.174152         0.189147
# 1942        0.564125      0.211369           1.164183         0.211369
#
#      SENT_INDEX_R_mv_ma_5  ...  SENT_INDEX_R_mv_ma_15 SENT_INDEX_R_ma_15  \
# 19               0.914014  ...               0.960114           0.160317
# 20               0.921298  ...               0.967765           0.160317
# 21               0.932217  ...               0.979235           0.144762
# 22               0.956201  ...               1.004428           0.144762
# 23               0.960222  ...               1.008653           0.122540
# ...                   ...  ...                    ...                ...
# 1938             1.936505  ...               1.824666           0.179215
# 1939             1.936334  ...               1.824505           0.184709
# 1940             1.922459  ...               1.811431           0.180476
# 1941             1.939972  ...               1.827933           0.184444
# 1942             1.956442  ...               1.843452           0.200846
#
#       img_neg_mv_ma_20 img_neg_ma_20  tex_neg_mv_ma_20 tex_neg_ma_20  \
# 19            0.992815      0.151190          0.992815      0.151190
# 20            0.984903      0.151190          1.000727      0.151190
# 21            0.996577      0.156190          0.988867      0.156190
# 22            1.022216      0.149047          1.014307      0.149047
# 23            1.026515      0.149047          1.018573      0.149047
# ...                ...           ...               ...           ...
# 1938          2.522706      0.202534          0.449771      0.202534
# 1939          2.522928      0.203206          0.449811      0.203206
# 1940           2.50485      0.186142          0.453034      0.186142
# 1941           2.48203      0.181976          0.457161      0.181976
# 1942          2.460959      0.196420           0.45328      0.196420
#
#       SENT_INDEX_mv_ma_20 SENT_INDEX_ma_20  SENT_INDEX_R_mv_ma_20  \
# 19               0.992815         0.151190               0.992815
# 20               1.000727         0.151190               1.000727
# 21               1.012588         0.156190               1.012588
# 22                1.03864         0.149047                1.03864
# 23               1.043008         0.149047               1.043008
# ...                   ...              ...                    ...
# 1938             1.562807         0.202534               1.927925
# 1939              1.56267         0.203206               1.927755
# 1940             1.551472         0.186142               1.913941
# 1941             1.565606         0.181976               1.931377
# 1942             1.552314         0.196420               1.947774
#
#      SENT_INDEX_R_ma_20
# 19             0.151190
# 20             0.151190
# 21             0.156190
# 22             0.149047
# 23             0.149047
# ...                 ...
# 1938           0.202534
# 1939           0.203206
# 1940           0.186142
# 1941           0.181976
# 1942           0.196420
#
# [1924 rows x 35 columns]

# %%
# 图像大小
plt.rcParams['font.family'] = 'Arial'  # 字体
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(20, 10))

# 把Trade_date转换为日期格式
df_res_mv['Trade_date'] = pd.to_datetime(df_res_mv['trade_date'])

# 设置Trade_date为索引
df_res_mv.set_index('Trade_date', inplace=True)

# 为每一个策略列绘制一条线
strategies = ['img_neg_mv_ma_5', 'img_neg_mv_ma_10', 'img_neg_mv_ma_15', 'img_neg_mv_ma_20']
for strategy in strategies:
    ax.plot(df_res_mv.index, df_res_mv[strategy], label=strategy)

# 添加图例
ax.legend()

# 显示图形
plt.show()

# %% [markdown]
# ### LSTM策略
# 见 IS-Commit-2.ipynb
